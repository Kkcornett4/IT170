# %%
from PIL import Image
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
def writeImage(image):
    img = Image.open(image)
    
    pdf = pytesseract.image_to_pdf_or_hocr(img, extension = 'pdf', config = '--pdf')
    
    with open('test.pdf', 'wb') as f:
        f.write(pdf)

# %%
#def writeImage(image):
    #print(pytesseract.image_to_string(Image.open(image)))

# %%
writeImage('Example image.png')
# Out:
# ---------------------------------------------------------------------------
# TesseractError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 writeImage('Example image.png')
#
# Cell In[13], line 4, in writeImage(image)
#       1 def writeImage(image):
#       2     img = Image.open(image)
# ----> 4     pdf = pytesseract.image_to_pdf_or_hocr(img, extension = 'pdf', config = '--pdf')
#       6     with open('test.pdf', 'wb') as f:
#       7         f.write(pdf)
#
# File ~\miniconda3\envs\py35\Lib\site-packages\pytesseract\pytesseract.py:513, in image_to_pdf_or_hocr(image, lang, config, nice, extension, timeout)
#     509     config = f'-c tessedit_create_hocr=1 {config.strip()}'
#     511 args = [image, extension, lang, config, nice, timeout, True]
# --> 513 return run_and_get_output(*args)
#
# File ~\miniconda3\envs\py35\Lib\site-packages\pytesseract\pytesseract.py:352, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     341 with save(image) as (temp_name, input_filename):
#     342     kwargs = {
#     343         'input_filename': input_filename,
#     344         'output_filename_base': temp_name,
#    (...)    349         'timeout': timeout,
#     350     }
# --> 352     run_tesseract(**kwargs)
#     353     return _read_output(
#     354         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     355         return_bytes,
#     356     )
#
# File ~\miniconda3\envs\py35\Lib\site-packages\pytesseract\pytesseract.py:284, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
# --> 284         raise TesseractError(proc.returncode, get_errors(error_string))
#
# TesseractError: (1, "Error, unknown command line argument '--pdf'")
